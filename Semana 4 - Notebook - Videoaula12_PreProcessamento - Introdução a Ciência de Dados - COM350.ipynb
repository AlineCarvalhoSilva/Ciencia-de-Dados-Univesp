# %% [markdown]
# #Demonstração Pré-Processamento de Dados
# ###Disciplina - Introdução a Ciência de Dados - Univesp
# ###Videoaula 12
# ###Prof. Dr. José Eduardo Santarem Segundo

# %% [markdown]
# #Importar Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# #Trabalhar com dados dos jogos de Tenis como exemplo.
# ### https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_2021.csv

# %%
dados=pd.read_csv('https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_2021.csv')

# %%
dados.head(5)
# Out:
#   tourney_id  tourney_name  ... loser_rank  loser_rank_points
# 0  2021-0499  Delray Beach  ...      119.0              566.0
# 1  2021-0499  Delray Beach  ...      789.0               22.0
# 2  2021-0499  Delray Beach  ...       74.0              877.0
# 3  2021-0499  Delray Beach  ...      101.0              733.0
# 4  2021-0499  Delray Beach  ...      293.0              171.0
#
# [5 rows x 49 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          2225 non-null   object
#  1   tourney_name        2225 non-null   object
#  2   surface             2225 non-null   object
#  3   draw_size           2225 non-null   int64
#  4   tourney_level       2225 non-null   object
#  5   tourney_date        2225 non-null   int64
#  6   match_num           2225 non-null   int64
#  7   winner_id           2225 non-null   int64
#  8   winner_seed         968 non-null    float64
#  9   winner_entry        363 non-null    object
#  10  winner_name         2225 non-null   object
#  11  winner_hand         2225 non-null   object
#  12  winner_ht           1950 non-null   float64
#  13  winner_ioc          2225 non-null   object
#  14  winner_age          2225 non-null   float64
#  15  loser_id            2225 non-null   int64
#  16  loser_seed          571 non-null    float64
#  17  loser_entry         543 non-null    object
#  18  loser_name          2225 non-null   object
#  19  loser_hand          2225 non-null   object
#  20  loser_ht            1765 non-null   float64
#  21  loser_ioc           2225 non-null   object
#  22  loser_age           2225 non-null   float64
#  23  score               2225 non-null   object
#  24  best_of             2225 non-null   int64
#  25  round               2225 non-null   object
#  26  minutes             2155 non-null   float64
#  27  w_ace               2143 non-null   float64
#  28  w_df                2143 non-null   float64
#  29  w_svpt              2143 non-null   float64
#  30  w_1stIn             2143 non-null   float64
#  31  w_1stWon            2143 non-null   float64
#  32  w_2ndWon            2143 non-null   float64
#  33  w_SvGms             2144 non-null   float64
#  34  w_bpSaved           2143 non-null   float64
#  35  w_bpFaced           2143 non-null   float64
#  36  l_ace               2143 non-null   float64
#  37  l_df                2143 non-null   float64
#  38  l_svpt              2143 non-null   float64
#  39  l_1stIn             2143 non-null   float64
#  40  l_1stWon            2143 non-null   float64
#  41  l_2ndWon            2143 non-null   float64
#  42  l_SvGms             2144 non-null   float64
#  43  l_bpSaved           2143 non-null   float64
#  44  l_bpFaced           2143 non-null   float64
#  45  winner_rank         2225 non-null   int64
#  46  winner_rank_points  2225 non-null   int64
#  47  loser_rank          2219 non-null   float64
#  48  loser_rank_points   2219 non-null   float64
# dtypes: float64(27), int64(8), object(14)
# memory usage: 851.9+ KB

# %%
dados.describe(include='all')
# Out:
#        tourney_id   tourney_name  ...   loser_rank  loser_rank_points
# count        2225           2225  ...  2219.000000        2219.000000
# unique         53             53  ...          NaN                NaN
# top      2021-580  Roland Garros  ...          NaN                NaN
# freq          127            127  ...          NaN                NaN
# mean          NaN            NaN  ...    95.658855        1382.136548
# std           NaN            NaN  ...   116.850495        1455.518327
# min           NaN            NaN  ...     1.000000           1.000000
# 25%           NaN            NaN  ...    38.000000         718.500000
# 50%           NaN            NaN  ...    71.000000         975.000000
# 75%           NaN            NaN  ...   110.000000        1585.000000
# max           NaN            NaN  ...  1761.000000       12113.000000
#
# [11 rows x 49 columns]

# %%
dados.isnull()
# Out:
#       tourney_id  tourney_name  ...  loser_rank  loser_rank_points
# 0          False         False  ...       False              False
# 1          False         False  ...       False              False
# 2          False         False  ...       False              False
# 3          False         False  ...       False              False
# 4          False         False  ...       False              False
# ...          ...           ...  ...         ...                ...
# 2220       False         False  ...       False              False
# 2221       False         False  ...       False              False
# 2222       False         False  ...       False              False
# 2223       False         False  ...       False              False
# 2224       False         False  ...       False              False
#
# [2225 rows x 49 columns]

# %% [markdown]
# ###Verificar valores nulos nas colunas

# %%
dados.isnull().sum()
# Out:
# tourney_id               0
# tourney_name             0
# surface                  0
# draw_size                0
# tourney_level            0
# tourney_date             0
# match_num                0
# winner_id                0
# winner_seed           1257
# winner_entry          1862
# winner_name              0
# winner_hand              0
# winner_ht              275
# winner_ioc               0
# winner_age               0
# loser_id                 0
# loser_seed            1654
# loser_entry           1682
# loser_name               0
# loser_hand               0
# loser_ht               460
# loser_ioc                0
# loser_age                0
# score                    0
# best_of                  0
# round                    0
# minutes                 70
# w_ace                   82
# w_df                    82
# w_svpt                  82
# w_1stIn                 82
# w_1stWon                82
# w_2ndWon                82
# w_SvGms                 81
# w_bpSaved               82
# w_bpFaced               82
# l_ace                   82
# l_df                    82
# l_svpt                  82
# l_1stIn                 82
# l_1stWon                82
# l_2ndWon                82
# l_SvGms                 81
# l_bpSaved               82
# l_bpFaced               82
# winner_rank              0
# winner_rank_points       0
# loser_rank               6
# loser_rank_points        6
# dtype: int64

# %% [markdown]
# ###Verificar coluna "winner_entry", que tem muitos valores nulos e indica como o vencedor entrou no torneio

# %%
dados['winner_entry'].describe()
# Out:
# count     363
# unique      6
# top         Q
# freq      203
# Name: winner_entry, dtype: object

# %%
dados['winner_entry'].unique()
# Out:
# array([nan, 'Q', 'WC', 'Alt', 'PR', 'LL', 'SE'], dtype=object)

# %% [markdown]
# ###Apagar todas as linhas que o atributo "loser_rank" é nulo, porque são poucas ocasioes e isso pode implicar erros nos resultados

# %%
dados.dropna(subset=['loser_rank'], inplace=True)

# %%
dados
# Out:
#      tourney_id  tourney_name  ... loser_rank  loser_rank_points
# 0     2021-0499  Delray Beach  ...      119.0              566.0
# 1     2021-0499  Delray Beach  ...      789.0               22.0
# 2     2021-0499  Delray Beach  ...       74.0              877.0
# 3     2021-0499  Delray Beach  ...      101.0              733.0
# 4     2021-0499  Delray Beach  ...      293.0              171.0
# ...         ...           ...  ...        ...                ...
# 2220  2021-9410    Nur-Sultan  ...      165.0              437.0
# 2221  2021-9410    Nur-Sultan  ...      150.0              498.0
# 2222  2021-9410    Nur-Sultan  ...       53.0             1295.0
# 2223  2021-9410    Nur-Sultan  ...      109.0              733.0
# 2224  2021-9410    Nur-Sultan  ...      134.0              564.0
#
# [2219 rows x 49 columns]

# %% [markdown]
# ###Apagar colunas que todos os valores são nulos

# %%
dados.dropna(axis=1, how= 'all')
# Out:
#      tourney_id  tourney_name  ... loser_rank  loser_rank_points
# 0     2021-0499  Delray Beach  ...      119.0              566.0
# 1     2021-0499  Delray Beach  ...      789.0               22.0
# 2     2021-0499  Delray Beach  ...       74.0              877.0
# 3     2021-0499  Delray Beach  ...      101.0              733.0
# 4     2021-0499  Delray Beach  ...      293.0              171.0
# ...         ...           ...  ...        ...                ...
# 2220  2021-9410    Nur-Sultan  ...      165.0              437.0
# 2221  2021-9410    Nur-Sultan  ...      150.0              498.0
# 2222  2021-9410    Nur-Sultan  ...       53.0             1295.0
# 2223  2021-9410    Nur-Sultan  ...      109.0              733.0
# 2224  2021-9410    Nur-Sultan  ...      134.0              564.0
#
# [2219 rows x 49 columns]

# %% [markdown]
# ###Alterar valor dos dados nulos em uma coluna

# %%
dados['loser_entry'].unique()
# Out:
# array([nan, 'Q', 'WC', 'Alt', 'PR', 'LL', 'SE'], dtype=object)

# %%
dados['loser_entry'].fillna(value='X',inplace=True)

# %%
dados['loser_entry'].unique()
# Out:
# array(['X', 'Q', 'WC', 'Alt', 'PR', 'LL', 'SE'], dtype=object)

# %% [markdown]
# ###Alterar mais de um atributo, com condições diferentes

# %%
dados['w_ace'].unique()
# Out:
# array([ 4.,  7.,  6.,  2.,  5.,  3., 22., 10.,  9., 13., 27.,  0.,  8.,
#         1., 15., 12., nan, 11., 14., 23., 17., 16., 18., 41., 26., 19.,
#        21., 30., 25., 20., 29., 32., 28., 24., 34., 36., 44., 33., 49.,
#        31.])

# %%
dados['loser_ht'].unique()
# Out:
# array([196.,  nan, 188., 185., 206., 198., 191., 208., 183., 180., 193.,
#        178., 175., 190., 181., 211., 203., 173., 170., 172.])

# %%
dados.fillna(value={'w_ace':0,'loser_ht':dados['loser_ht'].mean()},inplace=True)

# %%
dados['w_ace'].unique()
# Out:
# array([ 4.,  7.,  6.,  2.,  5.,  3., 22., 10.,  9., 13., 27.,  0.,  8.,
#         1., 15., 12., 11., 14., 23., 17., 16., 18., 41., 26., 19., 21.,
#        30., 25., 20., 29., 32., 28., 24., 34., 36., 44., 33., 49., 31.])

# %%
dados['loser_ht'].unique()
# Out:
# array([196.        , 186.92512762, 188.        , 185.        ,
#        206.        , 198.        , 191.        , 208.        ,
#        183.        , 180.        , 193.        , 178.        ,
#        175.        , 190.        , 181.        , 211.        ,
#        203.        , 173.        , 170.        , 172.        ])

# %% [markdown]
# ###Usar o método ffill para projetar um dado para o registro seguinte

# %%
dados['minutes'][1975:1990]
# Out:
# 1981    128.0
# 1982     98.0
# 1983    119.0
# 1984      NaN
# 1985    141.0
# 1986     98.0
# 1987    127.0
# 1988      NaN
# 1989     98.0
# 1990     83.0
# 1991    135.0
# 1992     85.0
# 1993    140.0
# 1994    144.0
# 1995    131.0
# Name: minutes, dtype: float64

# %%
dados['minutes'].fillna(method='ffill',inplace=True)

# %%
dados['minutes'][1975:1990]
# Out:
# 1981    128.0
# 1982     98.0
# 1983    119.0
# 1984    119.0
# 1985    141.0
# 1986     98.0
# 1987    127.0
# 1988    127.0
# 1989     98.0
# 1990     83.0
# 1991    135.0
# 1992     85.0
# 1993    140.0
# 1994    144.0
# 1995    131.0
# Name: minutes, dtype: float64

# %% [markdown]
# ###Identificar duplicados

# %%
dados.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2220    False
# 2221    False
# 2222    False
# 2223    False
# 2224    False
# Length: 2219, dtype: bool

# %%
dados.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###Eliminar duplicados de uma coluna (nem sempre se quer realmente fazer isso, cuidado)

# %%
dados.drop_duplicates(subset=['tourney_name'],inplace=True)

# %%
dados['tourney_name'].head(10)
# Out:
# 0               Delray Beach
# 27                   Antalya
# 58     Great Ocean Road Open
# 113        Murray River Open
# 168                  Atp Cup
# 198          Australian Open
# 325                  Cordoba
# 352                Singapore
# 379              Montpellier
# 406             Buenos Aires
# Name: tourney_name, dtype: object

# %%
dados.describe()
# Out:
#         draw_size  tourney_date  ...  loser_rank  loser_rank_points
# count   53.000000  5.300000e+01  ...   53.000000          53.000000
# mean    47.924528  2.021051e+07  ...   65.396226        2183.943396
# std     29.524337  2.238309e+02  ...   57.586837        2558.803923
# min     12.000000  2.021010e+07  ...    1.000000         237.000000
# 25%     32.000000  2.021031e+07  ...   21.000000         816.000000
# 50%     32.000000  2.021052e+07  ...   50.000000        1139.000000
# 75%     64.000000  2.021071e+07  ...   95.000000        2423.000000
# max    128.000000  2.021092e+07  ...  255.000000       12113.000000
#
# [8 rows x 35 columns]

# %% [markdown]
# #Vamos ver como fazer um deslocamento
# ###Vamos importar os dados das ações da Apple
# ###https://finance.yahoo.com/quote/AAPL/history/

# %%
dados2=pd.read_csv("AAPL.csv")

# %%
dados2
# Out:
#            Date        Open        High  ...       Close   Adj Close     Volume
# 0    2020-09-08  113.949997  118.989998  ...  112.820000  112.098999  231366600
# 1    2020-09-09  117.260002  119.139999  ...  117.320000  116.570236  176940500
# 2    2020-09-10  120.360001  120.500000  ...  113.489998  112.764717  182274400
# 3    2020-09-11  114.570000  115.230003  ...  112.000000  111.284241  180860300
# 4    2020-09-14  114.720001  115.930000  ...  115.360001  114.622765  140150100
# ..          ...         ...         ...  ...         ...         ...        ...
# 247  2021-08-31  152.660004  152.800003  ...  151.830002  151.830002   86453100
# 248  2021-09-01  152.830002  154.979996  ...  152.509995  152.509995   80313700
# 249  2021-09-02  153.869995  154.720001  ...  153.649994  153.649994   71115500
# 250  2021-09-03  153.759995  154.630005  ...  154.300003  154.300003   57808700
# 251  2021-09-07  154.970001  156.229996  ...  155.660004  155.660004   31852614
#
# [252 rows x 7 columns]

# %%
dados2['close_ontem']=dados2['Close'].shift(1)

# %%
dados2
# Out:
#            Date        Open        High  ...   Adj Close     Volume  close_ontem
# 0    2020-09-08  113.949997  118.989998  ...  112.098999  231366600          NaN
# 1    2020-09-09  117.260002  119.139999  ...  116.570236  176940500   112.820000
# 2    2020-09-10  120.360001  120.500000  ...  112.764717  182274400   117.320000
# 3    2020-09-11  114.570000  115.230003  ...  111.284241  180860300   113.489998
# 4    2020-09-14  114.720001  115.930000  ...  114.622765  140150100   112.000000
# ..          ...         ...         ...  ...         ...        ...          ...
# 247  2021-08-31  152.660004  152.800003  ...  151.830002   86453100   153.119995
# 248  2021-09-01  152.830002  154.979996  ...  152.509995   80313700   151.830002
# 249  2021-09-02  153.869995  154.720001  ...  153.649994   71115500   152.509995
# 250  2021-09-03  153.759995  154.630005  ...  154.300003   57808700   153.649994
# 251  2021-09-07  154.970001  156.229996  ...  155.660004   31852614   154.300003
#
# [252 rows x 8 columns]

# %% [markdown]
# ###Nova coluna com a porcentagem de alteração de um dia para o outro

# %%
dados2['alteracao %']=((dados2['Close']/dados2['close_ontem'])-1)*100

# %%
dados2.head(20)
# Out:
#           Date        Open        High  ...     Volume  close_ontem  alteracao %
# 0   2020-09-08  113.949997  118.989998  ...  231366600          NaN          NaN
# 1   2020-09-09  117.260002  119.139999  ...  176940500   112.820000     3.988654
# 2   2020-09-10  120.360001  120.500000  ...  182274400   117.320000    -3.264577
# 3   2020-09-11  114.570000  115.230003  ...  180860300   113.489998    -1.312889
# 4   2020-09-14  114.720001  115.930000  ...  140150100   112.000000     3.000001
# 5   2020-09-15  118.330002  118.830002  ...  184642000   115.360001     0.156033
# 6   2020-09-16  115.230003  116.000000  ...  154679000   115.540001    -2.951362
# 7   2020-09-17  109.720001  112.199997  ...  178011000   112.129997    -1.596362
# 8   2020-09-18  110.400002  110.879997  ...  287104900   110.339996    -3.172014
# 9   2020-09-21  104.540001  110.190002  ...  195713800   106.839996     3.032578
# 10  2020-09-22  112.680000  112.860001  ...  183055400   110.080002     1.571581
# 11  2020-09-23  111.620003  112.110001  ...  150718700   111.809998    -4.194611
# 12  2020-09-24  105.169998  110.250000  ...  167743300   107.120003     1.026884
# 13  2020-09-25  108.430000  112.440002  ...  149981400   108.220001     3.751615
# 14  2020-09-28  115.010002  115.320000  ...  137672400   112.279999     2.386890
# 15  2020-09-29  114.550003  115.309998  ...   99382200   114.959999    -0.756788
# 16  2020-09-30  113.790001  117.260002  ...  142675200   114.089996     1.507584
# 17  2020-10-01  117.639999  117.720001  ...  116120400   115.809998     0.846216
# 18  2020-10-02  112.889999  115.370003  ...  144712000   116.790001    -3.228019
# 19  2020-10-05  113.910004  116.650002  ...  106243800   113.019997     3.079104
#
# [20 rows x 9 columns]

# %%
dados2.dropna(subset=['alteracao %'], inplace=True)

# %%
dados2
# Out:
#            Date        Open        High  ...     Volume  close_ontem  alteracao %
# 1    2020-09-09  117.260002  119.139999  ...  176940500   112.820000     3.988654
# 2    2020-09-10  120.360001  120.500000  ...  182274400   117.320000    -3.264577
# 3    2020-09-11  114.570000  115.230003  ...  180860300   113.489998    -1.312889
# 4    2020-09-14  114.720001  115.930000  ...  140150100   112.000000     3.000001
# 5    2020-09-15  118.330002  118.830002  ...  184642000   115.360001     0.156033
# ..          ...         ...         ...  ...        ...          ...          ...
# 247  2021-08-31  152.660004  152.800003  ...   86453100   153.119995    -0.842472
# 248  2021-09-01  152.830002  154.979996  ...   80313700   151.830002     0.447865
# 249  2021-09-02  153.869995  154.720001  ...   71115500   152.509995     0.747491
# 250  2021-09-03  153.759995  154.630005  ...   57808700   153.649994     0.423045
# 251  2021-09-07  154.970001  156.229996  ...   31852614   154.300003     0.881401
#
# [251 rows x 9 columns]

# %%
dados2.describe(include= 'all')
# Out:
#               Date        Open  ...  close_ontem  alteracao %
# count          251  251.000000  ...   251.000000   251.000000
# unique         251         NaN  ...          NaN          NaN
# top     2021-07-08         NaN  ...          NaN          NaN
# freq             1         NaN  ...          NaN          NaN
# mean           NaN  129.123546  ...   128.960916     0.145274
# std            NaN   11.173863  ...    11.246876     1.846480
# min            NaN  104.540001  ...   106.839996    -5.601803
# 25%            NaN  120.715000  ...   120.649997    -0.842301
# 50%            NaN  127.820000  ...   127.449997     0.109688
# 75%            NaN  135.744996  ...   134.930000     1.267132
# max            NaN  154.970001  ...   154.300003     6.352057
#
# [11 rows x 9 columns]

# %% [markdown]
# ###Transformar dados categóricos (qualitativos) em dados numéricos

# %%
dados=pd.read_csv('https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_2021.csv')

# %%
dados['winner_ioc']
# Out:
# 0       POL
# 1       POL
# 2       USA
# 3       USA
# 4       POL
#        ...
# 2220    ITA
# 2221    KOR
# 2222    BLR
# 2223    ESP
# 2224    SRB
# Name: winner_ioc, Length: 2225, dtype: object

# %%
dados['winner_ioc'].unique()
# Out:
# array(['POL', 'USA', 'GBR', 'ITA', 'ECU', 'COL', 'CRO', 'BRA', 'AUS',
#        'KAZ', 'FRA', 'BEL', 'GER', 'GEO', 'BUL', 'TUR', 'FIN', 'ESP',
#        'RUS', 'SRB', 'NED', 'URU', 'SLO', 'RSA', 'DEN', 'KOR', 'UKR',
#        'CAN', 'SUI', 'CZE', 'LTU', 'BLR', 'ARG', 'POR', 'HUN', 'JPN',
#        'GRE', 'AUT', 'NOR', 'MDA', 'SWE', 'SVK', 'CHI', 'IND', 'TUN',
#        'PER', 'TPE', 'BIH', 'BOL'], dtype=object)

# %% [markdown]
# ###Veja a documentação do scikit-learn sobre preprocessing!!!!

# %%
from sklearn.preprocessing import LabelEncoder

# %%
paises=dados['winner_ioc']

# %%
paises
# Out:
# 0       POL
# 1       POL
# 2       USA
# 3       USA
# 4       POL
#        ...
# 2220    ITA
# 2221    KOR
# 2222    BLR
# 2223    ESP
# 2224    SRB
# Name: winner_ioc, Length: 2225, dtype: object

# %%
lencoder = LabelEncoder()
paises_numeros = lencoder.fit_transform(paises)
paises_numeros
# Out:
# array([34, 34, 48, ...,  5, 16, 39])

# %%
paises.head(10)
# Out:
# 0    POL
# 1    POL
# 2    USA
# 3    USA
# 4    POL
# 5    GBR
# 6    USA
# 7    USA
# 8    ITA
# 9    POL
# Name: winner_ioc, dtype: object

# %%
dados['paises_numeros']=paises_numeros

# %%
dados
# Out:
#      tourney_id  tourney_name  ... loser_rank_points  paises_numeros
# 0     2021-0499  Delray Beach  ...             566.0              34
# 1     2021-0499  Delray Beach  ...              22.0              34
# 2     2021-0499  Delray Beach  ...             877.0              48
# 3     2021-0499  Delray Beach  ...             733.0              48
# 4     2021-0499  Delray Beach  ...             171.0              34
# ...         ...           ...  ...               ...             ...
# 2220  2021-9410    Nur-Sultan  ...             437.0              25
# 2221  2021-9410    Nur-Sultan  ...             498.0              28
# 2222  2021-9410    Nur-Sultan  ...            1295.0               5
# 2223  2021-9410    Nur-Sultan  ...             733.0              16
# 2224  2021-9410    Nur-Sultan  ...             564.0              39
#
# [2225 rows x 50 columns]
